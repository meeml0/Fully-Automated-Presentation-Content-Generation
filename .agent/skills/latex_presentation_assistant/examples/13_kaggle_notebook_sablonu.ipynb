# %% [markdown]
# # 🎓 MAT204 – Olasılık ve İstatistik: Haftalık Uygulama Defteri Şablonu
#
# Bu şablon, **konu anlatımı ile öğrenci uygulamasını** birleştiren standart bir Notebook yapısı sunar. Her hafta bu yapıyı kopyalayarak içeriği değiştirebilirsiniz.
#
# **Ders Akışı:**
# 1. **Teori ve Örnek:** Hoca konuyu anlatır ve Python kodunu gösterir.
# 2. **Uygulama:** Öğrenci verilen örneği çalıştırır ve inceler.
# 3. **Sıra Sizde:** Öğrenci benzer bir problemi sıfırdan kendisi çözer.
#
# > **Öğrenci Yönergesi:** Yukarıdaki "Copy & Edit" butonuna basarak kendi kopyanızı oluşturun ve "Sıra Sizde" bölümlerini tamamlayın.

# %% [markdown]
# ---

# %% [markdown]
# ## 📚 Bölüm 1: [Konu Başlığı Buraya]
#
# Buraya konunun kısa bir özeti ve mühendislikteki önemi yazılır.
#
# **Örnek Senaryo:** [Senaryo Tanımı]

# %%
# Gerekli Kütüphaneler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# HOCA TARAFINDAN VERİLEN ÖRNEK KOD
# [Kodun ne yaptığına dair kısa açıklama]
data = [10, 20, 30, 40, 50]
print(f"Ortalama: {np.mean(data)}")

# Görselleştirme Örneği
plt.plot(data)
plt.title("Örnek Grafik")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🚀 SIRA SİZDE: Görev 1
#
# Aşağıdaki verileri kullanarak öğrendiğiniz yöntemi uygulayın.
#
# **Veri Seti:**
# Bir fabrikadaki üretim hataları: `[5, 8, 2, 4, 9, 1, 3]`
#
# **Yapılacaklar:**
# 1. Bu verinin ortalamasını hesaplayın.
# 2. Veriyi çizgi grafiği olarak görselleştirin.
# 3. En yüksek hata sayısını print ettirin.

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ---

# %% [markdown]
# ## 📚 Bölüm 2: [İkinci Konu Başlığı]
#
# Konu anlatımı devam eder...

# %%
# HOCA ÖRNEĞİ 2
# ...

# %% [markdown]
# ## 🚀 SIRA SİZDE: Görev 2
#
# Yeni görev tanımı...

# %%
# Kodunuzu buraya yazın

# %% [markdown]
# ---

# %% [markdown]
# ## 📝 Kapanış ve Teslim
#
# Bu notebook'u tamamladıktan sonra "Save Version" butonuna basarak kaydedin. Linki ödev teslim sistemine yükleyin.
